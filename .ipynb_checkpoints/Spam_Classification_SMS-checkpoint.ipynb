# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, precision_recall_curve, f1_score, recall_score, precision_score,classification_report,confusion_matrix,accuracy_score

# %%
df = pd.read_csv('super_sms_dataset.csv',encoding='ISO-8859-1')

# %%
df.sample(10)
# Out:
#                                                    SMSes  Labels
# 11875  Dear Patym customer your patym KYC have be sus...     1.0
# 24214  hi customer  deals for u  buy  get  free on sh...     1.0
# 54757  happy to launch india s most rewarding loyalty...     1.0
# 11064  rejoice flipkarts biggest fashion sale is here...     1.0
# 42754  colorbar wishes you a very happy and colorful ...     1.0
# 3701                      Ooo okay! Nia is sick I heard!     0.0
# 27354                                   Merry chirstmas!     0.0
# 36315       Hey gals... Tmr meet wat time... N where....     0.0
# 45651         Sorry, I'll call later, busy at the moment     0.0
# 63810  spencers lknw zyada ka faydamaybuy daawat deva...     1.0

# %%
df = df.dropna(subset=['Labels'])


# Convert the 'Labels' column from float to int
df.loc[:,'Labels'] = df['Labels'].astype(int)

# Now you can use the updated DataFrame as needed
print(df.head())
# Out:
#                                                SMSes  Labels
# 0  There be an update for your delivery CC 017281...     1.0
# 1  watch your favorite english movies of all genr...     1.0
# 2                     aur what is the status for fms     0.0
# 3  hi shalini sundi thank you for dialling  speci...     1.0
# 4                       m tryin to understand too...     0.0

# %%
df.shape
# Out:
# (67008, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67008 entries, 0 to 67009
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SMSes   67008 non-null  object
#  1   Labels  67008 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# SMSes     0
# Labels    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (67008, 2)

# %%
df['Labels'].value_counts()
# Out:
# Labels
# 0.0    40830
# 1.0    26178
# Name: count, dtype: int64

# %%
# Fill NaN values with an empty string
df['SMSes'] = df['SMSes'].fillna('')

# Convert all values in the 'SMSes' column to strings
df['SMSes'] = df['SMSes'].astype(str)
print(df.head())
# Out:
#                                                SMSes  Labels
# 0  There be an update for your delivery CC 017281...     1.0
# 1  watch your favorite english movies of all genr...     1.0
# 2                     aur what is the status for fms     0.0
# 3  hi shalini sundi thank you for dialling  speci...     1.0
# 4                       m tryin to understand too...     0.0

# %%
plt.pie(df['Labels'].value_counts(), labels = ['ham','spam'],autopct="%0.2f")
plt.figure(figsize=(20,20))
plt.show()

# %%
import nltk

df['num_characters'] = df['SMSes'].apply(len)

# %%
df['num_words'] = df['SMSes'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df['num_sentences'] = df['SMSes'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head(5)
# Out:
#                                                SMSes  Labels  num_characters  \
# 0  There be an update for your delivery CC 017281...     1.0              93
# 1  watch your favorite english movies of all genr...     1.0             146
# 2                     aur what is the status for fms     0.0              30
# 3  hi shalini sundi thank you for dialling  speci...     1.0             112
# 4                       m tryin to understand too...     0.0              28
#
#    num_words  num_sentences
# 0         16              1
# 1         26              1
# 2          7              1
# 3         21              1
# 4          6              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters     num_words  num_sentences
# count    67008.000000  67008.000000   67008.000000
# mean        96.095347     19.332483       1.626283
# std         68.756854     12.880638       1.162588
# min          2.000000      1.000000       1.000000
# 25%         42.000000     10.000000       1.000000
# 50%         89.000000     18.000000       1.000000
# 75%        136.000000     25.000000       2.000000
# max       2695.000000    528.000000      38.000000

# %%
df[df['Labels'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters     num_words  num_sentences
# count    40830.000000  40830.000000   40830.000000
# mean        65.190252     15.851531       1.908670
# std         56.576727     13.112047       1.319146
# min          2.000000      1.000000       1.000000
# 25%         30.000000      8.000000       1.000000
# 50%         50.000000     12.000000       2.000000
# 75%         81.000000     20.000000       2.000000
# max       1474.000000    343.000000      38.000000

# %%
df[df['Labels'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters     num_words  num_sentences
# count    26178.000000  26178.000000   26178.000000
# mean       144.298228     24.761747       1.185843
# std         57.405188     10.399891       0.653666
# min         19.000000      3.000000       1.000000
# 25%        121.000000     20.000000       1.000000
# 50%        136.000000     23.000000       1.000000
# 75%        150.000000     27.000000       1.000000
# max       2695.000000    528.000000      10.000000

# %%
import seaborn as sns
plt.figure(figsize=(20,14))
sns.histplot(df[df['Labels'] == 0]['num_characters'])
sns.histplot(df[df['Labels'] == 1]['num_characters'],color='red')
plt.show()

# %%
plt.figure(figsize=(20,14))
sns.histplot(df[df['Labels'] == 0]['num_words'])
sns.histplot(df[df['Labels'] == 1]['num_words'],color='red')
plt.show()

# %%
sns.pairplot(df,hue='Labels')
plt.show()

# %%
numeric_df = df.select_dtypes(include=[float, int])
plt.figure(figsize=(15,10))
sns.heatmap(numeric_df.corr(), annot=True)
plt.show()

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk
import string

lemmatizer = WordNetLemmatizer()

def transform_text(text):
    text = text.lower() #Lowercasing Text
    text = nltk.word_tokenize(text) #Tokenization
    
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text = y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    text = y[:]
    y.clear()
    
    for i in text:
        y.append(lemmatizer.lemmatize(i))  # Applying lemmatizer
    
    return " ".join(y)

# %%
df['preprocessed_text'] = df['SMSes'].apply(transform_text)

# %%
df.head(10)
# Out:
#                                                SMSes  Labels  num_characters  \
# 0  There be an update for your delivery CC 017281...     1.0              93
# 1  watch your favorite english movies of all genr...     1.0             146
# 2                     aur what is the status for fms     0.0              30
# 3  hi shalini sundi thank you for dialling  speci...     1.0             112
# 4                       m tryin to understand too...     0.0              28
# 5              vip number for sale   rs  cont kumar      1.0              37
# 6                          Hee. Muacks. Love u dear!     0.0              25
# 7  This be a reminder that your package will be d...     1.0              96
# 8                           Whoops let me convert it     0.0              24
# 9                              whats going on mate ?     0.0              21
#
#    num_words  num_sentences                                  preprocessed_text
# 0         16              1          update delivery cc 01728161e due tap http
# 1         26              1  watch favorite english movie genre like fast f...
# 2          7              1                                      aur status fm
# 3         21              1  hi shalini sundi thank dialling special offer ...
# 4          6              1                                   tryin understand
# 5          7              1                       vip number sale r cont kumar
# 6          8              3                             hee muacks love u dear
# 7         19              1  reminder package deliver receive 57 pending am...
# 8          5              1                                  whoop let convert
# 9          5              1                                   whats going mate

# %%
spam_corpus = []
for msg in df[df['Labels'] == 1]['preprocessed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
from collections import Counter

# Assuming spam_corpus is a list of words
word_counts = Counter(spam_corpus)

# Get the 30 most common words
most_common_words = word_counts.most_common(30)

# Print each word with its frequency
for word, freq in most_common_words:
    print(f"{word}: {freq}")
# Out:
# get: 8052
# r: 7661
# http: 5696
# offer: 5491
# call: 5121
# free: 4667
# dear: 3791
# please: 3369
# click: 3305
# customer: 2946
# day: 2935
# app: 2865
# account: 2707
# valid: 2472
# today: 2260
# download: 2245
# card: 2159
# apply: 2112
# visit: 2019
# xx: 1999
# till: 1998
# flat: 1902
# use: 1870
# tc: 1870
# link: 1869
# sm: 1860
# code: 1769
# update: 1658
# new: 1625
# order: 1622

# %%
len(spam_corpus)
# Out:
# 428389

# %%
from collections import Counter
plt.bar(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.figure(figsize=(30,20))
plt.show()

# %%
ham_corpus = []
for msg in df[df['Labels'] == 0]['preprocessed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 320163

# %%
from collections import Counter
plt.bar(pd.DataFrame(Counter(ham_corpus).most_common(30))[0],pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()

# %%
def save_corpora(spam_corpus, ham_corpus):
    """Save existing spam and ham corpora to files"""
    try:
        # Convert lists to space-separated strings
        spam_text = ' '.join(spam_corpus)
        ham_text = ' '.join(ham_corpus)
        
        # Save to files
        with open('spam_corpus.txt', 'w', encoding='utf-8') as f:
            f.write(spam_text)
        
        with open('ham_corpus.txt', 'w', encoding='utf-8') as f:
            f.write(ham_text)
            
        return True
    except Exception as e:
        print(f"Error saving corpora: {e}")
        return False

# Usage
save_corpora(spam_corpus, ham_corpus)
# Out:
# True

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=3000)
X = tfidf.fit_transform(df['preprocessed_text']).toarray()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Improved settings for SMS classification
tfidf = TfidfVectorizer(
    max_features=3000,         # Limit features to prevent overfitting
    ngram_range=(1, 2),        # Use unigrams and bigrams to capture context
    binary=True,  
    min_df=2,                   # Ignore terms that appear in fewer than 2 messages
    max_df=0.95,                # Ignore tokens appearing in more than 95% of messages (likely not discriminative)
    lowercase=True,             # Convert all texts to lowercase for consistency
    token_pattern=r'\b[a-zA-Z]{2,}\b'  # Only consider tokens with 2 or more alphabetic characters
)

X = tfidf.fit_transform(df['preprocessed_text']).toarray()

# %%
X.shape
# Out:
# (67008, 3000)

# %%
y = df['Labels'].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
#import imblearn
from imblearn.over_sampling import SMOTE
# Apply SMOTE
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Convert to DataFrame if needed
df_smote = pd.concat([pd.DataFrame(X_train_smote), pd.DataFrame(y_train_smote, columns=['Labels'])], axis=1)

# %%
df_smote

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(confusion_matrix(y_test,y_pred1))
print(classification_report(y_test,y_pred1))# for precision, recall, f1-score

# Calculate ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_pred1) 
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, y_pred1)

# Plot ROC curve
plt.figure(figsize=(10, 5)) 
plt.subplot(1, 2, 1) 
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})') 
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--') 
plt.xlim([0.0, 1.0]) 
plt.ylim([0.0, 1.05]) 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.title('Receiver Operating Characteristic (ROC) Curve') 
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2) 
plt.plot(recall, precision, color='green', lw=2, label='Precision-Recall curve') 
plt.xlabel('Recall') 
plt.ylabel('Precision') 
plt.title('Precision-Recall Curve') 
plt.legend(loc="lower left") 
plt.tight_layout() 
plt.show()
# Out:
# [[12027   231]
#  [  662  7183]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.96     12258
#          1.0       0.97      0.92      0.94      7845
#
#     accuracy                           0.96     20103
#    macro avg       0.96      0.95      0.95     20103
# weighted avg       0.96      0.96      0.96     20103

# %%
gnb.fit(X_train_smote,y_train_smote)
y_pred2 = gnb.predict(X_test)
print(confusion_matrix(y_test,y_pred2))
print(classification_report(y_test,y_pred2))# for precision, recall, f1-score

# Calculate ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_pred2) 
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, y_pred2)

# Plot ROC curve
plt.figure(figsize=(10, 5)) 
plt.subplot(1, 2, 1) 
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})') 
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--') 
plt.xlim([0.0, 1.0]) 
plt.ylim([0.0, 1.05]) 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.title('Receiver Operating Characteristic (ROC) Curve') 
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2) 
plt.plot(recall, precision, color='green', lw=2, label='Precision-Recall curve') 
plt.xlabel('Recall') 
plt.ylabel('Precision') 
plt.title('Precision-Recall Curve') 
plt.legend(loc="lower left") 
plt.tight_layout() 
plt.show()

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(confusion_matrix(y_test,y_pred3))
print(classification_report(y_test,y_pred3))# for precision, recall, f1-score

# Calculate ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_pred3) 
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, y_pred3)

# Plot ROC curve
plt.figure(figsize=(10, 5)) 
plt.subplot(1, 2, 1) 
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})') 
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--') 
plt.xlim([0.0, 1.0]) 
plt.ylim([0.0, 1.05]) 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.title('Receiver Operating Characteristic (ROC) Curve') 
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2) 
plt.plot(recall, precision, color='green', lw=2, label='Precision-Recall curve') 
plt.xlabel('Recall') 
plt.ylabel('Precision') 
plt.title('Precision-Recall Curve') 
plt.legend(loc="lower left") 
plt.tight_layout() 
plt.show()
# Out:
# [[12158   100]
#  [  373  7472]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98     12258
#          1.0       0.99      0.95      0.97      7845
#
#     accuracy                           0.98     20103
#    macro avg       0.98      0.97      0.98     20103
# weighted avg       0.98      0.98      0.98     20103

# %%
bnb.fit(X_train_smote,y_train_smote)
y_pred3 = bnb.predict(X_test)
print(confusion_matrix(y_test,y_pred3))
print(classification_report(y_test,y_pred3))# for precision, recall, f1-score

# Calculate ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_pred3) 
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, y_pred3)

# Plot ROC curve
plt.figure(figsize=(10, 5)) 
plt.subplot(1, 2, 1) 
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})') 
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--') 
plt.xlim([0.0, 1.0]) 
plt.ylim([0.0, 1.05]) 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.title('Receiver Operating Characteristic (ROC) Curve') 
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2) 
plt.plot(recall, precision, color='green', lw=2, label='Precision-Recall curve') 
plt.xlabel('Recall') 
plt.ylabel('Precision') 
plt.title('Precision-Recall Curve') 
plt.legend(loc="lower left") 
plt.tight_layout() 
plt.show()
# Out:
# [[12112   146]
#  [  247  7598]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.98     12258
#          1.0       0.98      0.97      0.97      7845
#
#     accuracy                           0.98     20103
#    macro avg       0.98      0.98      0.98     20103
# weighted avg       0.98      0.98      0.98     20103

# %%
mnb.fit(X_train,y_train)
y_pred4 = mnb.predict(X_test)
print(confusion_matrix(y_test,y_pred4))
print(classification_report(y_test,y_pred4))# for precision, recall, f1-score

# Calculate ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_pred4) 
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, y_pred4)

# Plot ROC curve
plt.figure(figsize=(10, 5)) 
plt.subplot(1, 2, 1) 
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})') 
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--') 
plt.xlim([0.0, 1.0]) 
plt.ylim([0.0, 1.05]) 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.title('Receiver Operating Characteristic (ROC) Curve') 
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2) 
plt.plot(recall, precision, color='green', lw=2, label='Precision-Recall curve') 
plt.xlabel('Recall') 
plt.ylabel('Precision') 
plt.title('Precision-Recall Curve') 
plt.legend(loc="lower left") 
plt.tight_layout() 
plt.show()
# Out:
# [[11845   413]
#  [  330  7515]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     12258
#          1.0       0.95      0.96      0.95      7845
#
#     accuracy                           0.96     20103
#    macro avg       0.96      0.96      0.96     20103
# weighted avg       0.96      0.96      0.96     20103

# %%
mnb.fit(X_train_smote,y_train_smote)
y_pred5 = mnb.predict(X_test)
print(confusion_matrix(y_test,y_pred5))
print(classification_report(y_test,y_pred5))# for precision, recall, f1-score

# Calculate ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_pred5) 
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, y_pred5)

# Plot ROC curve
plt.figure(figsize=(10, 5)) 
plt.subplot(1, 2, 1) 
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})') 
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--') 
plt.xlim([0.0, 1.0]) 
plt.ylim([0.0, 1.05]) 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.title('Receiver Operating Characteristic (ROC) Curve') 
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2) 
plt.plot(recall, precision, color='green', lw=2, label='Precision-Recall curve') 
plt.xlabel('Recall') 
plt.ylabel('Precision') 
plt.title('Precision-Recall Curve') 
plt.legend(loc="lower left") 
plt.tight_layout() 
plt.show()
# Out:
# [[11614   644]
#  [  238  7607]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.95      0.96     12258
#          1.0       0.92      0.97      0.95      7845
#
#     accuracy                           0.96     20103
#    macro avg       0.95      0.96      0.95     20103
# weighted avg       0.96      0.96      0.96     20103

# %%
import shap

# SHAP requires a callable function that outputs probabilities
# Use model.predict_proba for this
predict_fn = lambda x: bnb.predict_proba(x)[:, 1]  # Probability of class 1 (spam)

# Select a subset of the training data as background (e.g., 100 samples)
# This summarizes the "expected" feature distribution
background = X_train[:100]

# Initialize the SHAP KernelExplainer
explainer = shap.KernelExplainer(predict_fn, background)

# Compute SHAP values for the test set
shap_values = explainer.shap_values(X_test, nsamples=100)  # nsamples controls computation speed
# Out:
#   0%|          | 0/20103 [00:00<?, ?it/s]
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=5.338e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=5.338e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.083e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=6.330e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.321e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=3.932e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=6.069e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=6.091e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=7.098e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=6.507e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=5.162e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.435e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=4.308e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.928e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=5.812e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.214e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.358e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=4.725e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=4.654e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.075e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.156e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=5.430e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=6.427e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=5.688e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=6.148e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=8.130e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=1.075e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=7.168e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=1.538e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.309e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=9.506e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=9.911e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.142e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=9.469e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=5.710e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=6.694e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=7.160e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.261e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.143e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=6.297e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.067e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=9.739e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.843e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=4.804e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=8.414e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=5.696e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=1.238e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.156e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=6.774e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.595e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.412e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=8.939e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# ...
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.725e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=5.921e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=5.633e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.586e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.586e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.978e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=3.521e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=3.521e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=5.386e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.483e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.104e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=9.573e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=5.924e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=3.280e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=5.840e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=5.840e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.921e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=7.088e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=3.956e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=6.949e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=5.619e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(

# %%
shap.summary_plot(shap_values, X_test, feature_names=tfidf.get_feature_names_out())

# %%
import numpy as np
import pickle

# Save SHAP values to a file
with open('shap_values_spam.pkl', 'wb') as f:
    pickle.dump({
        'shap_values': shap_values,
        'expected_value': explainer.expected_value
    }, f)

# Later, you can load them like this:
# with open('shap_values.pkl', 'rb') as f:
#     shap_data = pickle.load(f)
#     shap_values = shap_data['shap_values']
#     expected_value = shap_data['expected_value']

print(f"SHAP values saved to 'shap_values_spam.pkl'")
# Out:
# SHAP values saved to 'shap_values_spam.pkl'

# %%
with open('shap_values_spam.pkl', 'rb') as f:
     shap_data = pickle.load(f)
     shap_values = shap_data['shap_values']
     expected_value = shap_data['expected_value']

# %%
# Create a SHAP waterfall plot for a single instance (e.g., the first test sample)
# First create an Explanation object
explanation = shap.Explanation(
    values=shap_values[0],
    base_values=explainer.expected_value,
    data=X_test[0],
    feature_names=tfidf.get_feature_names_out()
)

# Now create the waterfall plot
shap.plots.waterfall(explanation)

# %%
import shap

# SHAP requires a callable function that outputs probabilities
# Use model.predict_proba for this
predict_fn = lambda x: bnb.predict_proba(x)[:, 0]  # Probability of class 0 (ham)

# Select a subset of the training data as background (e.g., 100 samples)
# This summarizes the "expected" feature distribution
background = X_train[:100]

# Initialize the SHAP KernelExplainer
explainer = shap.KernelExplainer(predict_fn, background)

# Compute SHAP values for the test set
shap_values = explainer.shap_values(X_test, nsamples=100)  # nsamples controls computation speed
# Out:
#   0%|          | 0/20103 [00:00<?, ?it/s]
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.980e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.105e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=2.985e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=6.896e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=4.281e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=3.962e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.240e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=7.585e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=7.585e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=6.199e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=6.199e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.172e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=7.574e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.528e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=5.345e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.558e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=7.581e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=8.565e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=5.010e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=5.065e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.720e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.686e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.684e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=7.963e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=7.640e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.777e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.047e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.047e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=5.965e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.008e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=6.930e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.942e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.720e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.969e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=5.743e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.994e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=8.607e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.045e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=5.471e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=5.822e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=5.822e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.026e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.253e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.186e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=8.088e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.269e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=6.618e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=6.588e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=3.849e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.419e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=6.434e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.396e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# ...
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.286e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=6.704e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=6.857e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.691e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=6.283e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=6.983e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.705e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.347e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=4.237e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.951e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=3.914e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=3.914e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=6.531e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.467e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=5.329e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=5.329e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=9.724e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=3.509e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:645: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=4.575e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /home/user-1/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(

# %%
shap.summary_plot(shap_values, X_test, feature_names=tfidf.get_feature_names_out())

# %%
# Create a SHAP waterfall plot for a single instance (e.g., the first test sample)
# First create an Explanation object
explanation = shap.Explanation(
    values=shap_values[0],
    base_values=explainer.expected_value,
    data=X_test[0],
    feature_names=tfidf.get_feature_names_out()
)

# Now create the waterfall plot
shap.plots.waterfall(explanation)

# %%
import numpy as np
import pickle

# Save SHAP values to a file
with open('shap_values_ham.pkl', 'wb') as f:
    pickle.dump({
        'shap_values': shap_values,
        'expected_value': explainer.expected_value
    }, f)

# Later, you can load them like this:
# with open('shap_values.pkl', 'rb') as f:
#     shap_data = pickle.load(f)
#     shap_values = shap_data['shap_values']
#     expected_value = shap_data['expected_value']

print(f"SHAP values saved to 'shap_values_ham.pkl'")
# Out:
# SHAP values saved to 'shap_values_ham.pkl'

# %%
import numpy as np

pred_probs = bnb.predict_log_proba(X_test)
print(np.unique(pred_probs, axis=0))  # Check if all values are the same
# Out:
# [[-149.53534477    0.        ]
#  [-148.47686864    0.        ]
#  [-147.24267037    0.        ]
#  ...
#  [   0.          -32.72680942]
#  [   0.          -32.63213192]
#  [   0.          -31.94924399]]

# %%
import xgboost

model = xgboost.XGBClassifier(n_estimators=20,
                              max_depth=5, 
                              learning_rate=0.1,
                              tree_method='hist',
                              device='cuda',
                              random_state=42,
                              seed=42)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=20, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = model.predict(X_test)
# Out:
# /home/user-1/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [18:45:53] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8874794806745262

# %%
import shap
# build a Permutation explainer and explain the model predictions on the given dataset
explainer = shap.explainers.Tree(model, X_train[:20000])
shap_values = explainer(X_train[:1000])

# %%
feature_names = tfidf.get_feature_names_out()

# %%
shap.summary_plot(shap_values, X_test[:1000],feature_names=feature_names)

# %%
shap.plots.waterfall(shap_values[0], max_display=14)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=42)
abc = AdaBoostClassifier(n_estimators=50, random_state=42)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'BNB': bnb,
    'MNB': mnb,
    'GNB': gnb,
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc
}

# %%
from sklearn.metrics import confusion_matrix

def specificity_score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    return tn / (tn + fp)

# %%
def train_classifier(clf,X_train_smote,y_train_smote,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    recall = recall_score(y_test,y_pred)
    f1 = f1_score(y_test,y_pred)
    specificity = specificity_score(y_test,y_pred)
    
    return accuracy,precision,recall,f1,specificity

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.9736357757548625,
#  0.9712665893570416,
#  0.9608667941363926,
#  0.9660387030629245,
#  0.9818077989884157)

# %%
train_classifier(svc,X_train_smote,y_train_smote,X_test,y_test)
# Out:
# (0.9736357757548625,
#  0.9712665893570416,
#  0.9608667941363926,
#  0.9660387030629245,
#  0.9818077989884157)

# %%
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []
specificity_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision,current_recall,current_f1,current_specificity = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    print("Recall - ",current_recall)
    print("F1-score - ",current_f1)
    print("Specificity - ",current_specificity)
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
    recall_scores.append(current_recall)
    f1_scores.append(current_f1)
    specificity_scores.append(current_specificity)
# Out:
# For  SVC
# Accuracy -  0.9736357757548625
# Precision -  0.9712665893570416
# Recall -  0.9608667941363926
# F1-score -  0.9660387030629245
# Specificity -  0.9818077989884157
# For  KN
# Accuracy -  0.7836143859125504
# Precision -  0.9893587230467656
# Recall -  0.45035054174633526
# F1-score -  0.6189558514365803
# Specificity -  0.9968999836841247
# For  BNB
# Accuracy -  0.9805501666417947
# Precision -  0.981151562096566
# Recall -  0.9687699171446782
# F1-score -  0.9749214290295684
# Specificity -  0.9880894109969
# For  MNB
# Accuracy -  0.9626423916828334
# Precision -  0.9426004492138758
# Recall -  0.962906309751434
# F1-score -  0.9526451856989722
# Specificity -  0.9624734867025616
# For  GNB
# Accuracy -  0.9513505446948217
# Precision -  0.9233140180002466
# Recall -  0.9546207775653283
# F1-score -  0.938706442717473
# Specificity -  0.9492576276717246
# For  DT
# Accuracy -  0.8578819081729095
# Precision -  0.9564421669106882
# Recall -  0.6661567877629063
# F1-score -  0.7853332331504996
# Specificity -  0.9805841083374123
# For  LR
# Accuracy -  0.9729891061035666
# Precision -  0.9786313581541689
# Recall -  0.9515615041427661
# F1-score -  0.9649066115168358
# Specificity -  0.9867025615924294
# For  RF
# Accuracy -  0.9735860319355321
# Precision -  0.97138437741686
# Recall -  0.9606118546845124
# F1-score -  0.9659680830609498
# Specificity -  0.9818893783651493
# C:\Users\admin\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# For  AdaBoost
# Accuracy -  0.9453812863751679
# Precision -  0.9640940982253405
# Recall -  0.8933078393881453
# F1-score -  0.927352123858674
# Specificity -  0.9787077826725403

# %%
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []
specificity_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision,current_recall,current_f1,current_specificity = train_classifier(clf, X_train_smote,y_train_smote,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    print("Recall - ",current_recall)
    print("F1-score - ",current_f1)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
    recall_scores.append(current_recall)
    f1_scores.append(current_f1)
    specificity_scores.append(current_specificity)
# Out:
# For  SVC
# Accuracy -  0.9736357757548625
# Precision -  0.9712665893570416
# Recall -  0.9608667941363926
# F1-score -  0.9660387030629245
# For  KN
# Accuracy -  0.7836143859125504
# Precision -  0.9893587230467656
# Recall -  0.45035054174633526
# F1-score -  0.6189558514365803
# For  BNB
# Accuracy -  0.9805501666417947
# Precision -  0.981151562096566
# Recall -  0.9687699171446782
# F1-score -  0.9749214290295684
# For  MNB
# Accuracy -  0.9626423916828334
# Precision -  0.9426004492138758
# Recall -  0.962906309751434
# F1-score -  0.9526451856989722
# For  GNB
# Accuracy -  0.9513505446948217
# Precision -  0.9233140180002466
# Recall -  0.9546207775653283
# F1-score -  0.938706442717473
# For  DT
# Accuracy -  0.8578819081729095
# Precision -  0.9564421669106882
# Recall -  0.6661567877629063
# F1-score -  0.7853332331504996
# For  LR
# Accuracy -  0.9729891061035666
# Precision -  0.9786313581541689
# Recall -  0.9515615041427661
# F1-score -  0.9649066115168358
# For  RF
# Accuracy -  0.9735860319355321
# Precision -  0.97138437741686
# Recall -  0.9606118546845124
# F1-score -  0.9659680830609498
# C:\Users\admin\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# For  AdaBoost
# Accuracy -  0.9453812863751679
# Precision -  0.9640940982253405
# Recall -  0.8933078393881453
# F1-score -  0.927352123858674

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores,'Recall':recall_scores,'f1':f1_scores,'specificity':specificity_scores,}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#   Algorithm  Accuracy  Precision    Recall        f1  specificity
# 1        KN  0.783614   0.989359  0.450351  0.618956     0.996900
# 2       BNB  0.980550   0.981152  0.968770  0.974921     0.988089
# 6        LR  0.972989   0.978631  0.951562  0.964907     0.986703
# 7        RF  0.973586   0.971384  0.960612  0.965968     0.981889
# 0       SVC  0.973636   0.971267  0.960867  0.966039     0.981808
# 8  AdaBoost  0.945381   0.964094  0.893308  0.927352     0.978708
# 5        DT  0.857882   0.956442  0.666157  0.785333     0.980584
# 3       MNB  0.962642   0.942600  0.962906  0.952645     0.962473
# 4       GNB  0.951351   0.923314  0.954621  0.938706     0.949258

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")

# %%
performance_df1
# Out:
#    Algorithm     variable     value
# 0         KN     Accuracy  0.783614
# 1        BNB     Accuracy  0.980550
# 2         LR     Accuracy  0.972989
# 3         RF     Accuracy  0.973586
# 4        SVC     Accuracy  0.973636
# 5   AdaBoost     Accuracy  0.945381
# 6         DT     Accuracy  0.857882
# 7        MNB     Accuracy  0.962642
# 8        GNB     Accuracy  0.951351
# 9         KN    Precision  0.989359
# 10       BNB    Precision  0.981152
# 11        LR    Precision  0.978631
# 12        RF    Precision  0.971384
# 13       SVC    Precision  0.971267
# 14  AdaBoost    Precision  0.964094
# 15        DT    Precision  0.956442
# 16       MNB    Precision  0.942600
# 17       GNB    Precision  0.923314
# 18        KN       Recall  0.450351
# 19       BNB       Recall  0.968770
# 20        LR       Recall  0.951562
# 21        RF       Recall  0.960612
# 22       SVC       Recall  0.960867
# 23  AdaBoost       Recall  0.893308
# 24        DT       Recall  0.666157
# 25       MNB       Recall  0.962906
# 26       GNB       Recall  0.954621
# 27        KN           f1  0.618956
# 28       BNB           f1  0.974921
# 29        LR           f1  0.964907
# 30        RF           f1  0.965968
# 31       SVC           f1  0.966039
# 32  AdaBoost           f1  0.927352
# 33        DT           f1  0.785333
# 34       MNB           f1  0.952645
# 35       GNB           f1  0.938706
# 36        KN  specificity  0.996900
# 37       BNB  specificity  0.988089
# 38        LR  specificity  0.986703
# 39        RF  specificity  0.981889
# 40       SVC  specificity  0.981808
# 41  AdaBoost  specificity  0.978708
# 42        DT  specificity  0.980584
# 43       MNB  specificity  0.962473
# 44       GNB  specificity  0.949258

# %%
sns.catplot(x = 'Algorithm', y='value', 
               hue = 'variable',data=performance_df1, kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)

temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_scaling':accuracy_scores,'Precision_scaling':precision_scores,'Recall_scaling':recall_scores,'f1_scaling':f1_scores}).sort_values('Precision_scaling',ascending=False)

new_df = performance_df.merge(temp_df,on='Algorithm')

new_df_scaled = new_df.merge(temp_df,on='Algorithm')

temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_num_chars':accuracy_scores,'Precision_num_chars':precision_scores,'Recall_num_chars':recall_scores,'f1_num_chars':f1_scores}).sort_values('Precision_num_chars',ascending=False)

new_df_scaled.merge(temp_df,on='Algorithm')
# Out:
#   Algorithm  Accuracy  Precision    Recall        f1  specificity  \
# 0        KN  0.783614   0.989359  0.450351  0.618956     0.996900
# 1       BNB  0.980550   0.981152  0.968770  0.974921     0.988089
# 2        LR  0.972989   0.978631  0.951562  0.964907     0.986703
# 3        RF  0.973586   0.971384  0.960612  0.965968     0.981889
# 4       SVC  0.973636   0.971267  0.960867  0.966039     0.981808
# 5  AdaBoost  0.945381   0.964094  0.893308  0.927352     0.978708
# 6        DT  0.857882   0.956442  0.666157  0.785333     0.980584
# 7       MNB  0.962642   0.942600  0.962906  0.952645     0.962473
# 8       GNB  0.951351   0.923314  0.954621  0.938706     0.949258
#
#    Accuracy_scaling_x  Precision_scaling_x  Recall_scaling_x  f1_scaling_x  \
# 0            0.783614             0.989359          0.450351      0.618956
# 1            0.980550             0.981152          0.968770      0.974921
# 2            0.972989             0.978631          0.951562      0.964907
# 3            0.973586             0.971384          0.960612      0.965968
# 4            0.973636             0.971267          0.960867      0.966039
# 5            0.945381             0.964094          0.893308      0.927352
# 6            0.857882             0.956442          0.666157      0.785333
# 7            0.962642             0.942600          0.962906      0.952645
# 8            0.951351             0.923314          0.954621      0.938706
#
#    Accuracy_scaling_y  Precision_scaling_y  Recall_scaling_y  f1_scaling_y  \
# 0            0.783614             0.989359          0.450351      0.618956
# 1            0.980550             0.981152          0.968770      0.974921
# 2            0.972989             0.978631          0.951562      0.964907
# 3            0.973586             0.971384          0.960612      0.965968
# 4            0.973636             0.971267          0.960867      0.966039
# 5            0.945381             0.964094          0.893308      0.927352
# 6            0.857882             0.956442          0.666157      0.785333
# 7            0.962642             0.942600          0.962906      0.952645
# 8            0.951351             0.923314          0.954621      0.938706
#
#    Accuracy_num_chars  Precision_num_chars  Recall_num_chars  f1_num_chars
# 0            0.783614             0.989359          0.450351      0.618956
# 1            0.980550             0.981152          0.968770      0.974921
# 2            0.972989             0.978631          0.951562      0.964907
# 3            0.973586             0.971384          0.960612      0.965968
# 4            0.973636             0.971267          0.960867      0.966039
# 5            0.945381             0.964094          0.893308      0.927352
# 6            0.857882             0.956442          0.666157      0.785333
# 7            0.962642             0.942600          0.962906      0.952645
# 8            0.951351             0.923314          0.954621      0.938706

# %%
# Voting Classifier

svc = SVC(kernel='sigmoid', gamma=1.0,probability=True)
'''
mnb = MultinomialNB()
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
'''
from sklearn.ensemble import VotingClassifier

voting = VotingClassifier(estimators=[('svm', svc), ('rf', rfc), ('lr',lrc )],voting='soft')

# %%
voting.fit(X_train_smote,y_train_smote)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('rf',
#                               RandomForestClassifier(n_estimators=50,
#                                                      random_state=42)),
#                              ('lr',
#                               LogisticRegression(penalty='l1',
#                                                  solver='liblinear'))],
#                  voting='soft')

# %%
y_pred = voting.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9756255285280804
# Precision 0.9709280182810714

# %%
# Applying stacking
estimators=[('svm', svc), ('nb', mnb), ('lr', lrc)]
final_estimator=RandomForestClassifier()

# %%
from sklearn.ensemble import StackingClassifier
clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator)

# %%
clf.fit(X_train_smote,y_train_smote)
y_pred = clf.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.972143461174949
# Precision 0.9610992596310703

# %%
import pickle
pickle.dump(tfidf,open('vectorizer_super.pkl','wb'))
pickle.dump(bnb,open('model_bnb_super.pkl','wb'))

# %%
pickle.dump(clf,open('model_stacking_super.pkl','wb'))

# %%
# Load the vectorizer and model
with open('vectorizer_super.pkl', 'rb') as f:
    vectorizer = pickle.load(f)

with open('model_bnb_super.pkl', 'rb') as f:
    model = pickle.load(f)

# New text to predict
new_text = ["Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entr..."]

# Transform the new text using the vectorizer
new_text_vectorized = vectorizer.transform(new_text)

# Convert sparse matrix to dense format
new_text_vectorized_dense = new_text_vectorized.toarray()

# Make predictions using the model
prediction = model.predict(new_text_vectorized_dense)
print("Prediction:", prediction)
# Out:
# Prediction: [1.]
